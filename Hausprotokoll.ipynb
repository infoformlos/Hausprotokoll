# %%
from random import choice
import time

#bei den variablen für ereignisse könnten wir abhängig von eventuell ausgelesenen datenpunkten noch tatsächlich gemessene
#werte wie raumtemperatur, energiebilanz etc. als variable hinzunehmen

ereignisse = ['EIN POST-IT WIRD ANGEKLEBT', 'EINE SEITE WIRD UMGEBLÄTTERT',
              'EIN LINK WIRD ANGEKLICKT', 'DIE FARBE EINER BÜROKLAMMER WIRD AUSGEWÄHLT',
              'EINE TÜR WIRD GESCHLOSSEN', 'EINE GRAFIK LÄDT NICHT',
              'EINE TABELLE WiRD GEÖFFNET', 'EIN FREQUENZUMRICHTER WIRD AKTIVIERT',
              'DREHANTRIEB FÜR ARMATUREN AKTIVIERT', 'EINE SEITE WIRD VOR- UND WIEDER ZURÜCKGEBLÄTTERT',
              'ENTFERNTES LACHEN IN EINEM ANDEREN BÜRO', 'EINE ETWAS ZU LANGE PAUSE IN EINEM GESPRÄCH',
              'EIN VORSTELLUNGSGESPRÄCH NIMMT EINE ÜBERRASCHENDE WENDUNG', 'EIN THERMOSTAT REAGIERT',
              'VERÄNDERUNG DER AUßENLICHTSTÄRKE REGISTRIERT', 'CO2-WERT ERREICHT DIE BEHAGlICHKEITSGRENZE',
              'EIN ESSEN WIRD BESTELLT', 'EINE ABSPRACHE WIRD GEBROCHEN', 'EINE AUSSPRACHE VERLÄUFT ERGEBNISLOS',
              'DER KOPIERER STREIKT', 'DRUCKERTONER WIRD AUSGEWECHSELT', 'EINE KUGELSCHREIBERMINE SPRINGT HERAUS',
              'EINE PRÄSENTATION VERLÄUFT ANGENEHM', 'EIN DIKTAT WIRD ABGEBROCHEN',
              'EIN DIKTAT WIRD WIEDER AUFGENOMMEN', 'DIE MODERATION EINER TEAMSITZUNG BLEIBT AUS',
              'EIN FINGER SENKT SICH AUF DIE UMSCHALTTASTE', 'EINE E-MAIL BLEIBT IM ENTWURFSORDNER',
              'AUFZUG A FÄHRT NACH OBEN', 'AUFZUG B FÄHRT NACH OBEN', 'AUFZUG A FÄHRT NACH UNTEN',
              'AUFZUG B FÄHRT NACH UNTEN', 'EIN AUFZUG BLEIBT KURZZEITIG STEHEN',
              'ERZÄHLUNGEN VON EINER TEAMBUILDING-MAßNAHME', 'EIN VORTRAG WIRD EINGEÜBT',
              'MODERATORENKÄRTCHEN WERDEN GEORDNET', 'DAS QUIETSCHEN EINES STIFTES AUF WHITEBOARD',
              'ABLUFTVENTILATION SPRINGT AN', 'EIN EXPANSIONSVENTIL VERÄNDERT DEN KÄLTEMITTELDURCHFLUSS',
              'EIN SCHEINBARER DURCHBRUCH WIRD ERZIELT', 'EIN MILESTONE IM EXPANSIONSPROJEKT WIRD ERREICHT',
              'EIN AUTOMATIONSSCHWERPUNKT FÄLLT AUS', 'EIN HEIZKREISVERTEILER WIRD GEWARTET',
              'EIN KOMPRESSOR SPRINGT AN', 'EIN RAUMFÜHLER MISST KLEINE TEMPERATURVERÄNDERUNGEN',
              'PROJEKTZIELE WERDEN ANGEPASST', 'X SITZT IN IHREM BÜRO UND ARBEITET AN IHREM COMPUTER.',
              'JEMAND GEHT DEN FLUR ENTLANG UND TRÄGT EINEN STAPEL PAPIERE', 'EIN TEAM-MEETING FINDET STATT'
              'JEMAND SCHICKT EINE WÜTENDE E-MAIL AN SEINEN CHEF', 'AN DER KOPIERMASCHINE WERDEN DOKUMENTE FÜR EINE PRÄSENTATION ZUSAMMENGESTELLT.'
              'DER BÜROLEITER IST IN DER PAUSE, ER MACHT KAFFEE FÜR DAS TEAM', 'IN EINEM VIDEO-ANRUF MIT EINEM KUNDEN WIRD EIN NEUER VERTRAG DISKUTIERT',
              'JEMAND GEHT DURCH DAS POSTFACH UND TRÄUMT VON INBOX ZERO', 'MAN GEHT IN DIE LOBBY UND BEGRÜßT NEUE KUNDEN',
              'MAN IST IN EINEM TEAM-MEETING', 'AKQUISE-ANRUFE', 'GANTT-CHARTS WERDEN ERSTELLT', 'MAN HOLT STIFTE UND PAPIER FÜR ALLE',
              'PERFORMANCE-REVIEW', 'MAN ISST SANDWICHES UND CHATTET MIT KOLLEGEN.'
              ]

wahrheiten = ['A NAME MEANS A LOT JUST BY ITSELF',
            'A POSITIVE ATTITUDE MEANS ALL THE DIFFERENCE IN THE WORLD',
            'A RELAXED MAN IS NOT NECESSARILY A BETTER MAN', 'A SINCERE EFFORT IS ALL YOU CAN ASK',
            'A SINGLE EVENT CAN HAVE INFINITELY MANY INTERPRETATIONS', 'ABSTRACTION IS A TYPE OF DECADENCE',
            'AMBITION IS JUST AS DANGEROUS AS COMPLACENCY',
            'A LOT OF PROFESSIONALS ARE CRACKPOTS', 'A STRONG SENSE OF DUTY IMPRISONS YOU',
            'ABUSE OF POWER COMES AS NO SURPRISE', 'ACTION CAUSES MORE TROUBLE THAN THOUGHT',
            'ALIENATION PRODUCES ECCENTRICS OR REVOLUTIONARIES', 'ALL THINGS ARE DELICATELY INTERCONNECTED',
            'AMBIVALENCE CAN RUIN YOUR LIFE', 'AN ELITE IS INEVITABLE', 'ANIMALISM IS PERFECTLY HEALTHY',
            'ANY SURPLUS IS IMMORAL', 'ANYTHING IS A LEGITIMATE AREA OF INVESTIGATION',
            'ARTIFICIAL DESIRES ARE DESPOILING THE EARTH', 'AT TIMES INACTIVITY IS PREFERABLE TO MINDLESS FUNCTIONING'
            'AT TIMES YOUR UNCONSCIOUSNESS IS TRUER THAN YOUR CONSCIOUS MIND',
            'AUTOMATION IS DEADLY', 'BAD INTENTIONS CAN YIELD GOOD RESULTS',
            'BEING ALONE WITH YOURSELF IS INCREASINGLY UNPOPULAR', 'CONFUSING YOURSELF IS A WAY TO STAY HONEST',
            'DISGUST IS THE APPROPRIATE RESPONSE TO MOST SITUATIONS', 'DISORGANIZATION IS A KIND OF ANESTHESIA',
            'ELABORATION IS A FORM OF POLLUTION', 'EVERYONES WORK IS EQUALLY IMPORTANT',
            'MYTH CAN MAKE REALITY MORE INTELLIGIBLE', 'PLANNING FOR THE FUTURE IS ESCAPISM',
            'SOMETIMES THINGS SEEM TO HAPPEN OF THEIR OWN ACCORD', 'TECHNOLOGY WILL MAKE OR BREAK US',
            'THE NEW IS NOTHING BUT A RESTATEMENT OF THE OLD', 'YOU ARE GUILELESS IN YOUR DREAMS',
            'YOU OWE THE WORLD NOT THE OTHER WAY AROUND', 'YOU SHOULD STUDY AS MUCH AS POSSIBLE',
            'YOUR ACTIONS ARE POINTLESS IF NO ONE NOTICES', 'YOUR OLDEST FEARS ARE THE WORST ONES'
            ]

#Hier wird eine variable hinter der systemzeit ausgegeben, um die illusion des protokolls zu etablieren.
#Sinnvoll wäre hier, auf der Wand jeweils ein paar Sekunden Verzögerung (mit blinkendem cursor?) einzubauen.

for i in range (9):
    print('')
    print(time.strftime("%H:%M:%S") + ': ' + choice(ereignisse))
    print('')

print('')
print(time.strftime("%H:%M:%S") + ': ' + choice(wahrheiten))
print('')
# Out:
# 11:48:41: EIN FINGER SENKT SICH AUF DIE UMSCHALTTASTE
#
#
# 11:48:41: EIN TEAM-MEETING FINDET STATTJEMAND SCHICKT EINE WÜTENDE E-MAIL AN SEINEN CHEF
#
#
# 11:48:41: EIN DIKTAT WIRD ABGEBROCHEN
#
#
# 11:48:41: AUFZUG B FÄHRT NACH UNTEN
#
#
# 11:48:41: EINE TABELLE WiRD GEÖFFNET
#
#
# 11:48:41: IN EINEM VIDEO-ANRUF MIT EINEM KUNDEN WIRD EIN NEUER VERTRAG DISKUTIERT
#
#
# 11:48:41: EINE PRÄSENTATION VERLÄUFT ANGENEHM
#
#
# 11:48:41: GANTT-CHARTS WERDEN ERSTELLT
#
#
# 11:48:41: DAS QUIETSCHEN EINES STIFTES AUF WHITEBOARD
#
#
# 11:48:41: DISORGANIZATION IS A KIND OF ANESTHESIA
